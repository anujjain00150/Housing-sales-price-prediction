# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import matplotlib.image as mpimg

# %% [markdown]
# ### Another interesting observation is found using Tableau that when a building is near a school, prices are noticeably high. You can find my Tableau file from here: https://github.com/anujjain00150/Housing-sales-price-prediction

# %%
plt.figure(figsize=(15,10))
img = mpimg.imread('/Users/user/Desktop/' +'school_dist.png')
plt.axis('off')
plt.imshow(img)
plt.show()
